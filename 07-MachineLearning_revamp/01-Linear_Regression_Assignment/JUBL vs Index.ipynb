# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import plotly
import matplotlib.pyplot as plt

# %%
% matplotlib inline

# %%
# Load data
data1 = pd.read_csv('index.csv')
data2 = pd.read_csv('JUBLFOODALLN.csv')

# %%
data1.head()
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 0  01-Mar-2018  10479.95  10525.50  10447.15  10458.35      181378504
# 1  05-Mar-2018  10428.30  10428.70  10323.90  10358.85      199975720
# 2  06-Mar-2018  10420.50  10441.35  10215.90  10249.25      229782297
# 3  07-Mar-2018  10232.95  10243.35  10141.55  10154.20      257200599
# 4  08-Mar-2018  10216.25  10270.35  10146.40  10242.65      233377712
#
#    Turnover (Rs. Cr)
# 0           10179.48
# 1           10673.92
# 2           12143.95
# 3           12128.88
# 4           11479.51

# %%
data2.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  JUBLFOOD     EQ  01-Mar-2018     2034.00     2039.95     2047.30
# 1  JUBLFOOD     EQ  05-Mar-2018     2005.85     2005.00     2018.90
# 2  JUBLFOOD     EQ  06-Mar-2018     1997.60     2006.00     2040.95
# 3  JUBLFOOD     EQ  07-Mar-2018     1989.25     1990.00     2005.00
# 4  JUBLFOOD     EQ  08-Mar-2018     1978.25     1991.00     2021.00
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0    1995.65      2006.1      2005.85        2017.76                 423544
# 1    1975.25      1998.5      1997.60        1996.90                 499605
# 2    1972.20      1979.6      1989.25        2016.46                 866691
# 3    1969.00      1986.0      1978.25        1984.09                 499818
# 4    1962.00      2020.0      2010.45        1992.35                 503731
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
data1['Time'] = pd.to_datetime(data1['Date'])

# %%
fig,ax = plt.subplots(figsize=(15,4))
data1.plot(x='Time',y='Open',ax =ax)

# %%
data2.keys()
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty'],
#       dtype='object')

# %%
data2['Time'] = pd.to_datetime(data2['Date'])
fig,ax = plt.subplots(figsize=(15,4))
data2.plot(x='Time',y='Open Price',ax =ax)

# %%
data2_new = data2[data2['Time']> pd.to_datetime('2018-07-01')].copy()

# %%
fig,ax = plt.subplots(figsize=(15,4))
data2_new.plot(x='Time',y='Open Price',ax =ax)

# %%
data1_new = data1[data1['Time']> pd.to_datetime('2018-07-01')].copy()

# %%
fig,ax = plt.subplots(figsize=(15,4))
data1_new.plot(x='Time',y='Open',ax =ax)

# %%
plt.scatter(x=data1_new['Open'],y =data2_new['Open Price'])
