# %% [markdown]
#  - Reading
#  - Grayscale
#  - Kernel

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# creating random array in 0 -15
arr = np.random.randint(0,15,(10,10))
arr
# Out:
# array([[14,  5,  9,  9,  5,  2, 10, 13,  8,  0],
#        [ 5,  6, 10, 11,  2, 12,  3, 12, 11,  9],
#        [ 6, 10,  6,  6,  0, 12,  0,  9,  4, 11],
#        [11,  1,  0,  9,  4, 11,  2,  4,  9,  9],
#        [ 4, 12, 14,  8, 10,  0, 10, 13,  0, 10],
#        [ 2,  8,  2, 12,  2, 12,  8,  8, 12,  1],
#        [ 7,  9,  8,  3,  4, 11, 10,  6, 11, 13],
#        [ 0, 12, 12,  0,  3,  9,  5,  9, 11,  6],
#        [ 8,  2,  5,  6,  2,  4,  3,  2, 14, 12],
#        [12, 10,  8, 11,  2, 11, 11,  1, 11,  8]])

# %%
plt.imshow(arr,cmap='gray')

# %% [markdown]
# `PIL - RGB
# CV2 - BGR
# matplotlib - RGB`

# %%
import PIL

# %%
img = PIL.Image.open('image.jpg')

# %%
arr1 = np.array(img)

# %%
arr1.shape
# Out:
# (600, 900, 3)

# %%
plt.imshow(arr1)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\srikanth\anaconda\lib\site-packages (3.4.0.12)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\srikanth\anaconda\lib\site-packages (from opencv-python) (1.14.5)

# %%
import cv2 # computer vision

# %%
img = cv2.imread('image.jpg') # BGR
# B- Blue, G- Green, R-Red

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (600, 900, 3)

# %%
b = img[:,:,0]
g = img[:,:,1]
r = img[:,:,2]

# %%
plt.imshow(b,cmap='gray')

# %%
# Convert Into grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (600, 900)

# %%
plt.imshow(gray,cmap='gray')

# %%
COL = ['b','g','r']
for i in range(3):

    his = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(his,COL[i])
    
plt.show()

# %%
plt.hist(gray.ravel(),256,[0,256])
plt.show()

# %%
edge = cv2.Canny(gray,100,255)

# %%
plt.imshow(edge,cmap='gray')
