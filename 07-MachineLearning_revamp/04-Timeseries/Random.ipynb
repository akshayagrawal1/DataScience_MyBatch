# %%
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa

# %%
music = librosa.load('a2002011001-e02.wav')
m = music[0]

# %%
m
# Out:
# array([ 3.1988120e-07, -3.4002468e-07,  3.5029299e-07, ...,
#         2.6825950e-10, -1.6871693e-10,  0.0000000e+00], dtype=float32)

# %%
y = np.arange(0,m.shape[0])

# %%
plt.figure(figsize=(10,6))
plt.scatter(y,m)
plt.show()

# %%
plt.hist(m)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(y[0:1000],m[0:1000])
plt.show()

# %%
ipd.Audio(data=m,rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = np.random.normal(size=44100)

# %%
plt.hist(x)
# Out:
# (array([4.2000e+01, 4.5200e+02, 2.8970e+03, 9.0380e+03, 1.4218e+04,
#         1.1627e+04, 4.7450e+03, 9.6500e+02, 1.1100e+02, 5.0000e+00]),
#  array([-3.96599344, -3.1190846 , -2.27217575, -1.4252669 , -0.57835806,
#          0.26855079,  1.11545963,  1.96236848,  2.80927733,  3.65618617,
#          4.50309502]),
#  <a list of 10 Patch objects>)

# %%
ipd.Audio(data=x,rate=10000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x.shape
# Out:
# (44100,)

# %%
y = np.arange(0,44100)

# %%
plt.figure(figsize=(10,6))
plt.scatter(y,x)
plt.show()

# %%
import cv2

# %%
img =cv2.imread('imag.jpg')

# %%
plt.hist(img[:,1])
# Out:
# ([array([ 13.,  27., 101., 283., 230.,  30.,   0.,   0.,   0.,   0.]),
#   array([  8.,  68., 215., 314.,  79.,   0.,   0.,   0.,   0.,   0.]),
#   array([  6., 132., 231., 228.,  49.,   7.,   5.,   4.,   3.,  19.])],
#  array([  4. ,  29.1,  54.2,  79.3, 104.4, 129.5, 154.6, 179.7, 204.8,
#         229.9, 255. ]),
#  <a list of 3 Lists of Patches objects>)

# %%
plt.imshow(img)
