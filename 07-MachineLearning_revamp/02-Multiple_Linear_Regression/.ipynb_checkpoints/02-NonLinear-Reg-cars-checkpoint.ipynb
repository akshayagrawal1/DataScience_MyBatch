# %% [markdown]
# # Linear Regression

# %% [markdown]
# > ### $\hat y = a + b*X$
#     b = coefficient
#     a = intercept

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # working on a car dataset which contains
# - speed(mph)
# - stopping distance (ft)

# %%
sns.set(color_codes=True)

# %%
cars = pd.read_csv('./dataset/SpeedVsStopNADA.csv')
cars.head()
# Out:
#    Speed.mph  StopDist.ft
# 0          4            4
# 1          5            2
# 2          5            8
# 3          5            8
# 4          5            4

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 2 columns):
# Speed.mph      63 non-null int64
# StopDist.ft    63 non-null int64
# dtypes: int64(2)
# memory usage: 1.1 KB

# %% [markdown]
# ### Discriptive Stats

# %%
sns.FacetGrid(data=cars, aspect = 4)
sns.kdeplot(data=cars['Speed.mph'],shade=True)
sns.kdeplot(data=cars['StopDist.ft'],shade=True)

# %%
cars.keys()
# Out:
# Index(['Speed.mph', 'StopDist.ft'], dtype='object')

# %%
cars.head()
# Out:
#    Speed.mph  StopDist.ft
# 0          4            4
# 1          5            2
# 2          5            8
# 3          5            8
# 4          5            4

# %%
sns.relplot('Speed.mph','StopDist.ft',data=cars,kind='scatter',aspect=2)
plt.show()

# %%
sns.catplot('speed','dist',data=cars,kind='box',aspect=3)
plt.show()

# %%
#join plot
sns.relplot('speed','dist',data=cars,kind='scatter')
plt.show()

sns.jointplot('speed','dist',data=cars,kind='scatter')
plt.show()

sns.jointplot('speed','dist',data=cars,kind='kde')
plt.show()

# %%
import statsmodels.formula.api as smf

# %%
cars.keys()
# Out:
# Index(['speed', 'dist'], dtype='object')

# %%
model = smf.ols(formula="dist~speed",data=cars)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   dist   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     89.57
# Date:                Sun, 23 Dec 2018   Prob (F-statistic):           1.49e-12
# Time:                        22:42:06   Log-Likelihood:                -206.58
# No. Observations:                  50   AIC:                             417.2
# Df Residuals:                      48   BIC:                             421.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -17.5791      6.758     -2.601      0.012     -31.168      -3.990
# speed          3.9324      0.416      9.464      0.000       3.097       4.768
# ==============================================================================
# Omnibus:                        8.975   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.189
# Skew:                           0.885   Prob(JB):                       0.0167
# Kurtosis:                       3.893   Cond. No.                         50.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model1 = smf.ols(formula="dist~speed+0",data=cars)
results1 = model1.fit()

# %%
print(results1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   dist   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     423.5
# Date:                Sun, 23 Dec 2018   Prob (F-statistic):           9.23e-26
# Time:                        22:49:18   Log-Likelihood:                -209.87
# No. Observations:                  50   AIC:                             421.7
# Df Residuals:                      49   BIC:                             423.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# speed          2.9091      0.141     20.578      0.000       2.625       3.193
# ==============================================================================
# Omnibus:                       14.345   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.573
# Skew:                           1.202   Prob(JB):                     0.000415
# Kurtosis:                       4.302   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Covariance

# %%
cars.cov()
# Out:
#             speed        dist
# speed   27.959184  109.946939
# dist   109.946939  664.060816

# %% [markdown]
# >### Correlation coefficient (*r* )

# %%
cars.corr()
# Out:
#           speed      dist
# speed  1.000000  0.806895
# dist   0.806895  1.000000

# %%
results.params
# Out:
# Intercept   -17.579095
# speed         3.932409
# dtype: float64

# %%
results.rsquared
# Out:
# 0.6510793807582509

# %%
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
fig=sm.graphics.plot_regress_exog(results1,'speed',fig=fig)

# %%
sns.lmplot(x='speed',y='dist',data=cars,aspect=3)
